# %% [markdown]
# ## Overview
#
# 1. Load latent space vector MRI volumes from OneDrive
# 1. Generate the train/val/test split lists
# 1. Normalize each volume and output to disk (Colab runtime), sorted into subdirs for train/val/test
# 1. Copy the SEGM mask files into the same dir as the normalized latent space vectors
# 1. Zip
# 1. Download for upload to OneDrive

# %% [markdown]
# ## Set up

# %%
# mount google drive to see repository
import os

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

working_dir = '/content/drive/My Drive/github/BioCV_Su23/src'
os.chdir(working_dir)
# Out:
# Mounted at /content/drive

# %%
# !pip install -q onedrivedownloader

# %%
# basic needs
from onedrivedownloader import download
import nibabel as nib
import numpy as np
import random
import matplotlib.pyplot as plt
from google.colab import files

# custom utilities
from utils.mri_common import (split_subjects, collate_scans, get_data_stats,
                              normalize_collated_data, plot_scan_stats,
                              update_collated_stats, normalize_and_save,
                              copy_segm_files)

# %%
# seeding
random.seed(100)
np.random.seed(100)

# %%
# define global vars
DATA_DIR = "/content/data/"  # places this in colab runtime storage instead of gdrive
if not os.path.exists(DATA_DIR):
    # !mkdir $DATA_DIR

# specify where to get the data
LATENT_SPACE_VECTORS_DIR = os.path.join(DATA_DIR, "latent_space_vectors")
LATENT_SPACE_VECTORS_URL = "https://rice-my.sharepoint.com/:u:/g/personal/hl9_rice_edu/EVrWZoIYka9NgpECNhJvDmAB6D9WrMjh9x0mk59xl5Y8lg?e=KW6PS7"
LATENT_SPACE_VECTORS_FN = "latent_space_vectors.zip"

# Specify the scan types
STRUCT_SCANS = ['latent_vector_1', 'latent_vector_2', 'latent_vector_3']

# Output Dir
OUTPUT_DIR = '/content/data/latent_space_vectors_annot_reduced_norm'

# Reduced size files containing SEGM annotation masks
IMG_REDUCED_DIR = os.path.join(DATA_DIR, "images_annot_reduced")
IMAGES_ANNOT_REDUCED_URL = "https://rice-my.sharepoint.com/:u:/g/personal/hl9_rice_edu/EfqrvokObOJEhovsqLl_sscBgplo836OUdN5kJzAYqPZyg"
IMAGES_ANNOT_REDUCED_FNAME = "images_annot_reduced.zip"

# download the reduced dataset if the files have not already been downloaded
if not os.path.exists(LATENT_SPACE_VECTORS_DIR):
    download(LATENT_SPACE_VECTORS_URL, filename=os.path.join(DATA_DIR, LATENT_SPACE_VECTORS_FN), unzip_path=LATENT_SPACE_VECTORS_DIR)
    download(IMAGES_ANNOT_REDUCED_URL, filename=os.path.join(DATA_DIR, IMAGES_ANNOT_REDUCED_FNAME), unzip_path=IMG_REDUCED_DIR)
# Out:
# 100%|██████████| 1.30G/1.30G [00:28<00:00, 45.7MiB/s]
# Unzipping file...
# Extracting files: 100%|██████████| 441/441 [00:06<00:00, 63.46it/s]
# 100%|██████████| 1.46G/1.46G [00:23<00:00, 63.0MiB/s]
# Unzipping file...
# Extracting files: 100%|██████████| 736/736 [00:10<00:00, 72.50it/s]

# %% [markdown]
# The reduced dimensions data is unzipped into a nested folder structure. Fix that by moving the files up two levels and then remove the empty dirs

# %%
# !mv /content/data/images_annot_reduced/data/images_annot_reduced/* /content/data/images_annot_reduced/

# %%
# !rm -r /content/data/images_annot_reduced/data

# %% [markdown]
# ## QC Input data

# %%
# test load and visualize subject UPENN-GBM-00002
upenn00002_lsv1 = nib.load(os.path.join(LATENT_SPACE_VECTORS_DIR, 'UPENN-GBM-00002_latent_vector_1.nii.gz'))
upenn00002_lsv2 = nib.load(os.path.join(LATENT_SPACE_VECTORS_DIR, 'UPENN-GBM-00002_latent_vector_2.nii.gz'))
upenn00002_lsv3 = nib.load(os.path.join(LATENT_SPACE_VECTORS_DIR, 'UPENN-GBM-00002_latent_vector_3.nii.gz'))

fig, axs = plt.subplots(ncols=3)
axs[0].imshow(upenn00002_lsv1.get_fdata()[:, :, 73])
axs[0].set_title('latent vector 1')
axs[1].imshow(upenn00002_lsv2.get_fdata()[:, :, 73])
axs[1].set_title('latent vector 2')
axs[2].imshow(upenn00002_lsv3.get_fdata()[:, :, 73])
axs[2].set_title('latent vector 3')
plt.show()

# %%
# get the shape of the image array data
SCAN_SHAPE = tuple(upenn00002_lsv1.header['dim'][1:4])
print(f"Scan shape: {SCAN_SHAPE}")
# Out:
# Scan shape: (163, 193, 146)

# %%
# obtain all images
# first, reduced dimensions data
reduced_files = os.listdir(IMG_REDUCED_DIR)
reduced_files.sort()
print(f"Number of reduced images : {len(reduced_files)}")
print(reduced_files[:10])

# second, latent space representations
latent_space_files = os.listdir(LATENT_SPACE_VECTORS_DIR)
latent_space_files.sort()
print(f"Number of latent space images : {len(latent_space_files)}")
print(latent_space_files[:10])

# obtain unique subjects
subjects = []
for my_file in latent_space_files:
    subjects.append(my_file.split('_')[0])
subjects = list(set(subjects))
subjects.sort()
print(f"Number of subjects: {len(subjects)}")
print(subjects[:10])

# extract the subject scan for the first manually-revised segmentation label e.g. UPENN-GBM-00002_11
subj_file = subjects[0]
print('Example subject ID:', subj_file)
# Out:
# Number of reduced images : 735
# ['UPENN-GBM-00002_11_FLAIR_cut.nii.gz', 'UPENN-GBM-00002_11_T1GD_cut.nii.gz', 'UPENN-GBM-00002_11_T1_cut.nii.gz', 'UPENN-GBM-00002_11_T2_cut.nii.gz', 'UPENN-GBM-00002_11_segm_cut.nii.gz', 'UPENN-GBM-00006_11_FLAIR_cut.nii.gz', 'UPENN-GBM-00006_11_T1GD_cut.nii.gz', 'UPENN-GBM-00006_11_T1_cut.nii.gz', 'UPENN-GBM-00006_11_T2_cut.nii.gz', 'UPENN-GBM-00006_11_segm_cut.nii.gz']
# Number of latent space images : 441
# ['UPENN-GBM-00002_latent_vector_1.nii.gz', 'UPENN-GBM-00002_latent_vector_2.nii.gz', 'UPENN-GBM-00002_latent_vector_3.nii.gz', 'UPENN-GBM-00006_latent_vector_1.nii.gz', 'UPENN-GBM-00006_latent_vector_2.nii.gz', 'UPENN-GBM-00006_latent_vector_3.nii.gz', 'UPENN-GBM-00008_latent_vector_1.nii.gz', 'UPENN-GBM-00008_latent_vector_2.nii.gz', 'UPENN-GBM-00008_latent_vector_3.nii.gz', 'UPENN-GBM-00009_latent_vector_1.nii.gz']
# Number of subjects: 147
# ['UPENN-GBM-00002', 'UPENN-GBM-00006', 'UPENN-GBM-00008', 'UPENN-GBM-00009', 'UPENN-GBM-00011', 'UPENN-GBM-00013', 'UPENN-GBM-00014', 'UPENN-GBM-00016', 'UPENN-GBM-00017', 'UPENN-GBM-00018']
# Example subject ID: UPENN-GBM-00002

# %% [markdown]
# As expected &check;

# %% [markdown]
# ## Cube statistics and normalization test
#
# **note**: this section is for QC purposes. The next section is the actual normalization and output.

# %%
# collate all the images together into a single array
# note: this is memory intensive so use the High-Memory runtime
collated_img = collate_scans(
    subject_list=subjects,
    shape=SCAN_SHAPE,
    struct_scan_list=STRUCT_SCANS,
    scan_type='latent_vector',
    data_path=LATENT_SPACE_VECTORS_DIR
)
# Out:
# Working on subject no: 1 / 147
# Working on subject no: 2 / 147
# Working on subject no: 3 / 147
# Working on subject no: 4 / 147
# Working on subject no: 5 / 147
# Working on subject no: 6 / 147
# Working on subject no: 7 / 147
# Working on subject no: 8 / 147
# Working on subject no: 9 / 147
# Working on subject no: 10 / 147
# Working on subject no: 11 / 147
# Working on subject no: 12 / 147
# Working on subject no: 13 / 147
# Working on subject no: 14 / 147
# Working on subject no: 15 / 147
# Working on subject no: 16 / 147
# Working on subject no: 17 / 147
# Working on subject no: 18 / 147
# Working on subject no: 19 / 147
# Working on subject no: 20 / 147
# Working on subject no: 21 / 147
# Working on subject no: 22 / 147
# Working on subject no: 23 / 147
# Working on subject no: 24 / 147
# Working on subject no: 25 / 147
# Working on subject no: 26 / 147
# Working on subject no: 27 / 147
# Working on subject no: 28 / 147
# Working on subject no: 29 / 147
# Working on subject no: 30 / 147
# Working on subject no: 31 / 147
# Working on subject no: 32 / 147
# Working on subject no: 33 / 147
# Working on subject no: 34 / 147
# Working on subject no: 35 / 147
# Working on subject no: 36 / 147
# Working on subject no: 37 / 147
# Working on subject no: 38 / 147
# Working on subject no: 39 / 147
# Working on subject no: 40 / 147
# Working on subject no: 41 / 147
# Working on subject no: 42 / 147
# Working on subject no: 43 / 147
# Working on subject no: 44 / 147
# Working on subject no: 45 / 147
# Working on subject no: 46 / 147
# Working on subject no: 47 / 147
# Working on subject no: 48 / 147
# Working on subject no: 49 / 147
# Working on subject no: 50 / 147
# Working on subject no: 51 / 147
# Working on subject no: 52 / 147
# Working on subject no: 53 / 147
# Working on subject no: 54 / 147
# Working on subject no: 55 / 147
# Working on subject no: 56 / 147
# Working on subject no: 57 / 147
# Working on subject no: 58 / 147
# Working on subject no: 59 / 147
# Working on subject no: 60 / 147
# Working on subject no: 61 / 147
# Working on subject no: 62 / 147
# Working on subject no: 63 / 147
# Working on subject no: 64 / 147
# Working on subject no: 65 / 147
# Working on subject no: 66 / 147
# Working on subject no: 67 / 147
# Working on subject no: 68 / 147
# Working on subject no: 69 / 147
# Working on subject no: 70 / 147
# Working on subject no: 71 / 147
# Working on subject no: 72 / 147
# Working on subject no: 73 / 147
# Working on subject no: 74 / 147
# Working on subject no: 75 / 147
# Working on subject no: 76 / 147
# Working on subject no: 77 / 147
# Working on subject no: 78 / 147
# Working on subject no: 79 / 147
# Working on subject no: 80 / 147
# Working on subject no: 81 / 147
# Working on subject no: 82 / 147
# Working on subject no: 83 / 147
# Working on subject no: 84 / 147
# Working on subject no: 85 / 147
# Working on subject no: 86 / 147
# Working on subject no: 87 / 147
# Working on subject no: 88 / 147
# Working on subject no: 89 / 147
# Working on subject no: 90 / 147
# Working on subject no: 91 / 147
# Working on subject no: 92 / 147
# Working on subject no: 93 / 147
# Working on subject no: 94 / 147
# Working on subject no: 95 / 147
# Working on subject no: 96 / 147
# Working on subject no: 97 / 147
# Working on subject no: 98 / 147
# Working on subject no: 99 / 147
# Working on subject no: 100 / 147
# Working on subject no: 101 / 147
# Working on subject no: 102 / 147
# Working on subject no: 103 / 147
# Working on subject no: 104 / 147
# Working on subject no: 105 / 147
# Working on subject no: 106 / 147
# Working on subject no: 107 / 147
# Working on subject no: 108 / 147
# Working on subject no: 109 / 147
# Working on subject no: 110 / 147
# Working on subject no: 111 / 147
# Working on subject no: 112 / 147
# Working on subject no: 113 / 147
# Working on subject no: 114 / 147
# Working on subject no: 115 / 147
# Working on subject no: 116 / 147
# Working on subject no: 117 / 147
# Working on subject no: 118 / 147
# Working on subject no: 119 / 147
# Working on subject no: 120 / 147
# Working on subject no: 121 / 147
# Working on subject no: 122 / 147
# Working on subject no: 123 / 147
# Working on subject no: 124 / 147
# Working on subject no: 125 / 147
# Working on subject no: 126 / 147
# Working on subject no: 127 / 147
# Working on subject no: 128 / 147
# Working on subject no: 129 / 147
# Working on subject no: 130 / 147
# Working on subject no: 131 / 147
# Working on subject no: 132 / 147
# Working on subject no: 133 / 147
# Working on subject no: 134 / 147
# Working on subject no: 135 / 147
# Working on subject no: 136 / 147
# Working on subject no: 137 / 147
# Working on subject no: 138 / 147
# Working on subject no: 139 / 147
# Working on subject no: 140 / 147
# Working on subject no: 141 / 147
# Working on subject no: 142 / 147
# Working on subject no: 143 / 147
# Working on subject no: 144 / 147
# Working on subject no: 145 / 147
# Working on subject no: 146 / 147
# Working on subject no: 147 / 147

# %%
# calculate raw stats
raw_stats_arr = get_data_stats(
    subject_list=subjects,
    struct_scan_list=STRUCT_SCANS,
    scan_type='latent_vector',
    data_path=LATENT_SPACE_VECTORS_DIR
)
# Out:
# Working on Subject No: 1 / 147
# Working on Subject No: 2 / 147
# Working on Subject No: 3 / 147
# Working on Subject No: 4 / 147
# Working on Subject No: 5 / 147
# Working on Subject No: 6 / 147
# Working on Subject No: 7 / 147
# Working on Subject No: 8 / 147
# Working on Subject No: 9 / 147
# Working on Subject No: 10 / 147
# Working on Subject No: 11 / 147
# Working on Subject No: 12 / 147
# Working on Subject No: 13 / 147
# Working on Subject No: 14 / 147
# Working on Subject No: 15 / 147
# Working on Subject No: 16 / 147
# Working on Subject No: 17 / 147
# Working on Subject No: 18 / 147
# Working on Subject No: 19 / 147
# Working on Subject No: 20 / 147
# Working on Subject No: 21 / 147
# Working on Subject No: 22 / 147
# Working on Subject No: 23 / 147
# Working on Subject No: 24 / 147
# Working on Subject No: 25 / 147
# Working on Subject No: 26 / 147
# Working on Subject No: 103 / 147
# Working on Subject No: 104 / 147
# Working on Subject No: 105 / 147
# Working on Subject No: 106 / 147
# Working on Subject No: 107 / 147
# Working on Subject No: 108 / 147
# Working on Subject No: 109 / 147
# Working on Subject No: 110 / 147
# Working on Subject No: 111 / 147
# Working on Subject No: 112 / 147
# Working on Subject No: 113 / 147
# Working on Subject No: 114 / 147
# Working on Subject No: 115 / 147
# Working on Subject No: 116 / 147
# Working on Subject No: 117 / 147
# Working on Subject No: 118 / 147
# Working on Subject No: 119 / 147
# Working on Subject No: 120 / 147
# Working on Subject No: 121 / 147
# Working on Subject No: 122 / 147
# Working on Subject No: 123 / 147
# Working on Subject No: 124 / 147
# Working on Subject No: 125 / 147
# Working on Subject No: 126 / 147
# Working on Subject No: 127 / 147
# Working on Subject No: 128 / 147
# Working on Subject No: 129 / 147
# Working on Subject No: 130 / 147
# Working on Subject No: 131 / 147
# Working on Subject No: 132 / 147
# Working on Subject No: 133 / 147
# Working on Subject No: 134 / 147
# Working on Subject No: 135 / 147
# Working on Subject No: 136 / 147
# Working on Subject No: 137 / 147
# Working on Subject No: 138 / 147
# Working on Subject No: 139 / 147
# Working on Subject No: 140 / 147
# Working on Subject No: 141 / 147
# Working on Subject No: 142 / 147
# Working on Subject No: 143 / 147
# Working on Subject No: 144 / 147
# Working on Subject No: 145 / 147
# Working on Subject No: 146 / 147
# Working on Subject No: 147 / 147

# %%
# plot the updated stats
plot_scan_stats(
    updated_stats_arr,
    STRUCT_SCANS
)

# %% [markdown]
# ## Split into Train, Val, Test

# %%
train_list, reserve_list = split_subjects(subjects, split_ratio=0.6, seed=2023)
val_list, test_list = split_subjects(reserve_list, split_ratio=0.5, seed=2023)

# QC
print(len(train_list))
print(len(val_list))
print(len(test_list))
print(len(subjects) == (len(train_list) + len(val_list) + len(test_list)))
# Out:
# 88
# 30
# 29
# True

# %% [markdown]
# ## Normalize and Output 3D cubes

# %%
normalize_and_save(
    subjects_list=subjects,
    struct_scan_list=STRUCT_SCANS,
    data_dir=LATENT_SPACE_VECTORS_DIR,
    output_dir=OUTPUT_DIR,
    train_list=train_list,
    val_list=val_list,
    test_list=test_list,
    scan_type='latent_vector'
)
# Out:
# Working on subject no: 1 / 147
# Working on subject no: 2 / 147
# Working on subject no: 3 / 147
# Working on subject no: 4 / 147
# Working on subject no: 5 / 147
# Working on subject no: 6 / 147
# Working on subject no: 7 / 147
# Working on subject no: 8 / 147
# Working on subject no: 9 / 147
# Working on subject no: 10 / 147
# Working on subject no: 11 / 147
# Working on subject no: 12 / 147
# Working on subject no: 13 / 147
# Working on subject no: 14 / 147
# Working on subject no: 15 / 147
# Working on subject no: 16 / 147
# Working on subject no: 17 / 147
# Working on subject no: 18 / 147
# Working on subject no: 19 / 147
# Working on subject no: 20 / 147
# Working on subject no: 21 / 147
# Working on subject no: 22 / 147
# Working on subject no: 23 / 147
# Working on subject no: 24 / 147
# Working on subject no: 25 / 147
# Working on subject no: 26 / 147
# Working on subject no: 27 / 147
# Working on subject no: 28 / 147
# Working on subject no: 29 / 147
# Working on subject no: 30 / 147
# Working on subject no: 31 / 147
# Working on subject no: 32 / 147
# Working on subject no: 33 / 147
# Working on subject no: 34 / 147
# Working on subject no: 35 / 147
# Working on subject no: 36 / 147
# Working on subject no: 37 / 147
# Working on subject no: 38 / 147
# Working on subject no: 39 / 147
# Working on subject no: 40 / 147
# Working on subject no: 41 / 147
# Working on subject no: 42 / 147
# Working on subject no: 43 / 147
# Working on subject no: 44 / 147
# Working on subject no: 45 / 147
# Working on subject no: 46 / 147
# Working on subject no: 47 / 147
# Working on subject no: 48 / 147
# Working on subject no: 49 / 147
# Working on subject no: 50 / 147
# Working on subject no: 51 / 147
# Working on subject no: 52 / 147
# Working on subject no: 53 / 147
# Working on subject no: 54 / 147
# Working on subject no: 55 / 147
# Working on subject no: 56 / 147
# Working on subject no: 57 / 147
# Working on subject no: 58 / 147
# Working on subject no: 59 / 147
# Working on subject no: 60 / 147
# Working on subject no: 61 / 147
# Working on subject no: 62 / 147
# Working on subject no: 63 / 147
# Working on subject no: 64 / 147
# Working on subject no: 65 / 147
# Working on subject no: 66 / 147
# Working on subject no: 67 / 147
# Working on subject no: 68 / 147
# Working on subject no: 69 / 147
# Working on subject no: 70 / 147
# Working on subject no: 71 / 147
# Working on subject no: 72 / 147
# Working on subject no: 73 / 147
# Working on subject no: 74 / 147
# Working on subject no: 75 / 147
# Working on subject no: 76 / 147
# Working on subject no: 77 / 147
# Working on subject no: 78 / 147
# Working on subject no: 79 / 147
# Working on subject no: 80 / 147
# Working on subject no: 81 / 147
# Working on subject no: 82 / 147
# Working on subject no: 83 / 147
# Working on subject no: 84 / 147
# Working on subject no: 85 / 147
# Working on subject no: 86 / 147
# Working on subject no: 87 / 147
# Working on subject no: 88 / 147
# Working on subject no: 89 / 147
# Working on subject no: 90 / 147
# Working on subject no: 91 / 147
# Working on subject no: 92 / 147
# Working on subject no: 93 / 147
# Working on subject no: 94 / 147
# Working on subject no: 95 / 147
# Working on subject no: 96 / 147
# Working on subject no: 97 / 147
# Working on subject no: 98 / 147
# Working on subject no: 99 / 147
# Working on subject no: 100 / 147
# Working on subject no: 101 / 147
# Working on subject no: 102 / 147
# Working on subject no: 103 / 147
# Working on subject no: 104 / 147
# Working on subject no: 105 / 147
# Working on subject no: 106 / 147
# Working on subject no: 107 / 147
# Working on subject no: 108 / 147
# Working on subject no: 109 / 147
# Working on subject no: 110 / 147
# Working on subject no: 111 / 147
# Working on subject no: 112 / 147
# Working on subject no: 113 / 147
# Working on subject no: 114 / 147
# Working on subject no: 115 / 147
# Working on subject no: 116 / 147
# Working on subject no: 117 / 147
# Working on subject no: 118 / 147
# Working on subject no: 119 / 147
# Working on subject no: 120 / 147
# Working on subject no: 121 / 147
# Working on subject no: 122 / 147
# Working on subject no: 123 / 147
# Working on subject no: 124 / 147
# Working on subject no: 125 / 147
# Working on subject no: 126 / 147
# Working on subject no: 127 / 147
# Working on subject no: 128 / 147
# Working on subject no: 129 / 147
# Working on subject no: 130 / 147
# Working on subject no: 131 / 147
# Working on subject no: 132 / 147
# Working on subject no: 133 / 147
# Working on subject no: 134 / 147
# Working on subject no: 135 / 147
# Working on subject no: 136 / 147
# Working on subject no: 137 / 147
# Working on subject no: 138 / 147
# Working on subject no: 139 / 147
# Working on subject no: 140 / 147
# Working on subject no: 141 / 147
# Working on subject no: 142 / 147
# Working on subject no: 143 / 147
# Working on subject no: 144 / 147
# Working on subject no: 145 / 147
# Working on subject no: 146 / 147
# Working on subject no: 147 / 147

# %%
# test load and visualize
upenn00006_lsv1 = nib.load(os.path.join(OUTPUT_DIR, 'train', 'UPENN-GBM-00006_11_latent_vector_1.nii.gz'))
upenn00006_lsv2 = nib.load(os.path.join(OUTPUT_DIR, 'train', 'UPENN-GBM-00006_11_latent_vector_2.nii.gz'))
upenn00006_lsv3 = nib.load(os.path.join(OUTPUT_DIR, 'train', 'UPENN-GBM-00006_11_latent_vector_3.nii.gz'))

# create a list of the volumes for easy access during visualization
lsv_vols = [upenn00006_lsv1, upenn00006_lsv2, upenn00006_lsv3]

fig, axs = plt.subplots(ncols=3)
for idx in range(len(lsv_vols)):
    axs[idx].imshow(lsv_vols[idx].get_fdata()[:, :, 73], vmin=0, vmax=1)
    axs[idx].set_title(f'latent vector {idx + 1}')
    # turn off ticks and labels
    axs[idx].tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
plt.show()

# %% [markdown]
# Looks good &check;

# %% [markdown]
# ## Add the associated SEGM files from the reduced files dir to the latent space vectors dir

# %%
# copy the associated SEGM annotation masks into OUTPUT_DIR
copy_segm_files(
    OUTPUT_DIR,
    IMG_REDUCED_DIR,
    subjects,
    train_list,
    val_list,
    test_list
)

# %%
# qc plot

# load the associated SEGM for subject UPENN-GBM-00002
upenn00006_segm = nib.load(os.path.join(OUTPUT_DIR, 'train', 'UPENN-GBM-00006_11_segm.nii.gz'))

# get the segment labels for visualization (colorbar, labelling, and transparency)
label_names = np.unique(upenn00006_segm.get_fdata().astype('uint'))
num_labels = len(label_names)
label_cmap = plt.get_cmap('gnuplot', num_labels)
# because it is difficult to find a nice colorbar that works well with alpha
# blending, create an alpha masking array to make any pixel with a label value
# of 0 equal to alpha=0, and all else 0.4
alpha_mask = np.where(upenn00006_segm.get_fdata().astype('uint') == 0, 0, 0.4)

# plot
fig, axs = plt.subplots(ncols=3)
for idx in range(3):
    lsv_curr = lsv_vols[idx]
    axs[idx].imshow(lsv_curr.get_fdata()[:, :, 73], cmap='Greys', vmin=0, vmax=1)
    axs[idx].set_title(f'latent vector {idx + 1}')
    # add the segmentation mask
    mask = axs[idx].imshow(upenn00006_segm.get_fdata().astype('uint')[:, :, 73], cmap=label_cmap, alpha=alpha_mask[:, :, 73])
    # add a colorbar to each plot
    mask_cbar = fig.colorbar(mask, ax=axs[idx], fraction=0.05)
    # set the tick locs and adjust the cbar
    mask_cbar.set_ticks([tick + 0.5 for tick in range(num_labels)])
    mask_cbar.set_ticklabels(label_names)
    # turn off ticks and labels
    axs[idx].tick_params(left = False, right = False , labelleft = False ,
                labelbottom = False, bottom = False)
plt.show()

# %% [markdown]
# Lookcs good &check;

# %% [markdown]
# ## Zip the files together and download
#
# **note**: in order to avoid the zipped archive containing the full directory structure, first cd into the dir and zip all contents from inside, placing the target zip file one dir above inside /data

# %%
# !cd /content/data/latent_space_vectors_annot_reduced_norm/ && zip -r ../latent_space_vectors_annot_reduced_norm.zip *
# Out:
#   adding: test/ (stored 0%)
#   adding: test/UPENN-GBM-00330_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00215_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00062_11_latent_vector_1.nii.gz (deflated 0%)
#   adding: test/UPENN-GBM-00330_11_segm.nii.gz (deflated 24%)
#   adding: test/UPENN-GBM-00002_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00266_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00156_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00002_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00026_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00277_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00113_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00418_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00173_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00196_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00113_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00215_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00026_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00351_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00115_11_segm.nii.gz (deflated 68%)
#   adding: test/UPENN-GBM-00193_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00149_11_segm.nii.gz (deflated 30%)
#   adding: test/UPENN-GBM-00196_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00193_11_segm.nii.gz (deflated 26%)
#   adding: test/UPENN-GBM-00351_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00368_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00173_11_segm.nii.gz (deflated 30%)
#   adding: test/UPENN-GBM-00146_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00368_11_segm.nii.gz (deflated 40%)
#   adding: test/UPENN-GBM-00270_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00115_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00115_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00136_11_segm.nii.gz (deflated 25%)
#   adding: test/UPENN-GBM-00277_11_segm.nii.gz (deflated 41%)
#   adding: test/UPENN-GBM-00136_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00227_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00373_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00106_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00384_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00266_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00270_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00256_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00113_11_segm.nii.gz (deflated 28%)
#   adding: test/UPENN-GBM-00062_11_latent_vector_2.nii.gz (deflated 0%)
#   adding: test/UPENN-GBM-00113_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00149_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00418_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00373_11_segm.nii.gz (deflated 49%)
#   adding: test/UPENN-GBM-00026_11_segm.nii.gz (deflated 47%)
#   adding: test/UPENN-GBM-00146_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00238_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00238_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00014_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00277_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00256_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00146_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00059_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00014_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00215_11_segm.nii.gz (deflated 39%)
#   adding: test/UPENN-GBM-00351_11_segm.nii.gz (deflated 37%)
#   adding: test/UPENN-GBM-00238_11_segm.nii.gz (deflated 55%)
#   adding: test/UPENN-GBM-00156_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00227_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00146_11_segm.nii.gz (deflated 69%)
#   adding: test/UPENN-GBM-00270_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00330_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00147_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00156_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00196_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00002_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00373_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00384_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00059_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00014_11_segm.nii.gz (deflated 22%)
#   adding: test/UPENN-GBM-00238_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00227_11_segm.nii.gz (deflated 14%)
#   adding: test/UPENN-GBM-00062_11_latent_vector_3.nii.gz (deflated 0%)
#   adding: test/UPENN-GBM-00227_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00062_11_segm.nii.gz (deflated 40%)
#   adding: test/UPENN-GBM-00196_11_segm.nii.gz (deflated 33%)
#   adding: test/UPENN-GBM-00156_11_segm.nii.gz (deflated 39%)
#   adding: test/UPENN-GBM-00026_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00266_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00266_11_segm.nii.gz (deflated 72%)
#   adding: test/UPENN-GBM-00149_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00173_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00277_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00418_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00270_11_segm.nii.gz (deflated 48%)
#   adding: test/UPENN-GBM-00106_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00173_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00418_11_segm.nii.gz (deflated 47%)
#   adding: test/UPENN-GBM-00368_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00002_11_segm.nii.gz (deflated 21%)
#   adding: test/UPENN-GBM-00106_11_segm.nii.gz (deflated 71%)
#   adding: test/UPENN-GBM-00059_11_segm.nii.gz (deflated 24%)
#   adding: test/UPENN-GBM-00106_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00136_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00149_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00384_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00147_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00330_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-00384_11_segm.nii.gz (deflated 35%)
#   adding: test/UPENN-GBM-00136_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: test/UPENN-GBM-
11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00284_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00075_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00249_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00380_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00101_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00284_11_segm.nii.gz (deflated 27%)
#   adding: val/UPENN-GBM-00086_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00261_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00439_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00013_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00054_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00033_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00240_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00140_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00217_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00217_11_segm.nii.gz (deflated 26%)
#   adding: val/UPENN-GBM-00144_11_segm.nii.gz (deflated 27%)
#   adding: val/UPENN-GBM-00264_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00264_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00101_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00151_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00030_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00008_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00261_11_segm.nii.gz (deflated 38%)
#   adding: val/UPENN-GBM-00240_11_segm.nii.gz (deflated 38%)
#   adding: val/UPENN-GBM-00144_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00261_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00124_11_segm.nii.gz (deflated 35%)
#   adding: val/UPENN-GBM-00240_11_latent_vector_2.nii.gz (deflated 0%)
#   adding: val/UPENN-GBM-00118_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00131_11_segm.nii.gz (deflated 42%)
#   adding: val/UPENN-GBM-00118_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00144_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00105_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00033_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00264_11_segm.nii.gz (deflated 56%)
#   adding: val/UPENN-GBM-00020_11_latent_vector_1.nii.gz (deflated 0%)
#   adding: val/UPENN-GBM-00206_11_segm.nii.gz (deflated 60%)
#   adding: val/UPENN-GBM-00033_11_segm.nii.gz (deflated 40%)
#   adding: val/UPENN-GBM-00086_11_segm.nii.gz (deflated 27%)
#   adding: val/UPENN-GBM-00474_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00205_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00284_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00144_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00249_11_segm.nii.gz (deflated 28%)
#   adding: val/UPENN-GBM-00249_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00259_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00131_11_latent_vector_3.nii.gz (deflated 0%)
#   adding: val/UPENN-GBM-00008_11_segm.nii.gz (deflated 53%)
#   adding: val/UPENN-GBM-00439_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00217_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00020_11_latent_vector_3.nii.gz (deflated 0%)
#   adding: val/UPENN-GBM-00151_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00474_11_segm.nii.gz (deflated 39%)
#   adding: val/UPENN-GBM-00100_11_latent_vector_3.nii.gz (deflated 0%)
#   adding: val/UPENN-GBM-00259_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00105_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00105_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00033_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00140_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00124_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00259_11_segm.nii.gz (deflated 44%)
#   adding: val/UPENN-GBM-00474_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00100_11_segm.nii.gz (deflated 21%)
#   adding: val/UPENN-GBM-00264_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00205_11_segm.nii.gz (deflated 26%)
#   adding: val/UPENN-GBM-00008_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00013_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00105_11_segm.nii.gz (deflated 42%)
#   adding: val/UPENN-GBM-00205_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00217_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00086_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00124_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00118_11_segm.nii.gz (deflated 24%)
#   adding: val/UPENN-GBM-00380_11_segm.nii.gz (deflated 56%)
#   adding: val/UPENN-GBM-00206_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00054_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00151_11_segm.nii.gz (deflated 32%)
#   adding: val/UPENN-GBM-00474_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00030_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00205_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00140_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00020_11_segm.nii.gz (deflated 55%)
#   adding: val/UPENN-GBM-00101_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00261_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00075_11_segm.nii.gz (deflated 55%)
#   adding: val/UPENN-GBM-00284_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00140_11_segm.nii.gz (deflated 43%)
#   adding: val/UPENN-GBM-00253_11_latent_vector_2.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00118_11_latent_vector_1.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00253_11_segm.nii.gz (deflated 28%)
#   adding: val/UPENN-GBM-00253_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00054_11_segm.nii.gz (deflated 23%)
#   adding: val/UPENN-GBM-00131_11_latent_vector_2.nii.gz (deflated 0%)
#   adding: val/UPENN-GBM-00030_11_latent_vector_3.nii.gz (deflated 1%)
#   adding: val/UPENN-GBM-00380_11_latent_vector_3.nii.gz (deflated 1%)

# %%
# download -- be patient this is slow
files.download(os.path.join(DATA_DIR, "latent_space_vectors_annot_reduced_norm.zip"))

# %% [markdown]
# --> files.download() took over an hour to download a 1.2 GB file, which is absurd. Try copying it to the mounted Google Drive, instead, for quicker turn-around.
