# %%
# this notebook has one purpose and that is to import every single package required by our code
# which is then used by pipreqsnb to generate our requirements.txt file

# note, there may be additional packages used for each module; however, once it is included we do 
# not re-duplicate below

# included w/ standard Python library 3.10
import os
import tempfile
import enum
import io
import typing
import shutil
import importlib
import base64
import json
import time
import tarfile
import re
import random


# src/utils/data_handler.py
import torch
import nibabel as nib
import numpy as np
import onedrivedownloader

# src/utils/google_storage.py
import google.cloud

# src/utils make_autoencoder_dataset.py
import torch 
import torch.utils.data 

# src/utils/metrics.py
import medpy.metric.binary 
import scipy.ndimage 

# src/utils/mri_plotter.py
import matplotlib.pyplot

# src/visualization/MRI_visualization.ipynb
import slicer
import requests

# src/exploratory_data_analysis
import gzip  # included w/ standard Python library
import sklearn.decomposition

# src/auto_segm_versus_segm.ipynb
import google.colab
import joblib
import matplotlib.ticker
import matplotlib.patches
import pandas as pd
import seaborn as sns

# src/CNN_Cancer_Classifier3.ipynb
import sklearn.metrics
import cv2
import torch.nn
import torch.utils.data
import torchvision
import tqdm.auto
import livelossplot

# src/maskformer_pilot_share_metrics.ipynb
import torchinfo
import albumentations
import datasets
import PIL
import transformers

# src/MRI_data_prep_and_loading.ipynb
# nothing new to add

# src/prototype_conv_autoencoder.ipynb
import torchsummary

# src/models/autoencoder.py
# nothing new to add
