# %%
# mount google drive to see repository
import os

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

working_dir = '/content/drive/My Drive/BioCV_Su23/src'
os.chdir(working_dir)
# Out:
# Mounted at /content/drive

# %%
# !pip install pipreqsnb
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pipreqsnb: filename=pipreqsnb-0.2.4-py3-none-any.whl size=4128 sha256=fb61452c1c8924f104bcbfb181f689f0722f9115238517d2a23dd83fa67158f5
#   Stored in directory: /root/.cache/pip/wheels/c3/1b/47/ca78a979321cb4bf9e812da5157fb754712f43d094bc60bf61
# Successfully built pipreqsnb
# ...

# %%
# !ls -l .
# Out:
# total 31976
# drwx------ 2 root root     4096 Jun 29 01:58 auth
# -rw------- 1 root root   556879 Jun 29 01:58 auto_segm_versus_segm.ipynb
# -rw------- 1 root root  2978817 Jun 29 01:58 CNN_Cancer_Classifier3.ipynb
# -rw------- 1 root root  4005109 Jun 29 01:58 exploratory_data_analysis.ipynb
# -rw------- 1 root root 16339744 Jun 29 01:58 Maskformer_pilot_share.ipynb
# -rw------- 1 root root  4146227 Jun 29 01:58 maskformer_pilot_share_metrics.ipynb
# drwx------ 2 root root     4096 Jun 29 01:58 models
# -rw------- 1 root root  3024695 Jun 29 01:58 MRI_data_prep_and_loading.ipynb
# -rw------- 1 root root  1673542 Jun 29 01:58 prototype_conv_autoencoder.ipynb
# drwx------ 2 root root     4096 Jun 29 01:58 utils
# drwx------ 2 root root     4096 Jun 29 01:58 visualization

# %%
# !pipreqsnb . --encoding 'utf8' --savepath '../requirements.txt'
# Out:
# Exception occurred while working on file /content/drive/MyDrive/BioCV_Su23/src/MRI_data_prep_and_loading.ipynb, cell 43/82
# Traceback (most recent call last):
#   File "/usr/local/bin/pipreqsnb", line 8, in <module>
#     sys.exit(main())
#   File "/usr/local/lib/python3.10/dist-packages/pipreqsnb/pipreqsnb.py", line 130, in main
#     raise e
#   File "/usr/local/lib/python3.10/dist-packages/pipreqsnb/pipreqsnb.py", line 126, in main
#     imports += get_import_string_from_source(source)
#   File "/usr/local/lib/python3.10/dist-packages/pipreqsnb/pipreqsnb.py", line 26, in get_import_string_from_source
#     tree = ast.parse(source)
#   File "/usr/lib/python3.10/ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#   File "<unknown>", line 12
#     !cp  $file_from $file_to
#     ^
# SyntaxError: invalid syntax
