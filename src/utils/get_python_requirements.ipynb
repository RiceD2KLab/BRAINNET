# %%
# mount google drive to see repository
import os

from google.colab import drive
drive.mount('/content/drive', force_remount=True)

working_dir = '/content/drive/My Drive/github/BioCV_Su23/src'
os.chdir(working_dir)
# Out:
# Mounted at /content/drive

# %% [markdown]
# install pipreqsnb

# %%
# !pip install pipreqsnb
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pipreqsnb: filename=pipreqsnb-0.2.4-py3-none-any.whl size=4128 sha256=09d4d8fa433d964cf493a5dc1ea3370db33fe5e86a8dc0d4f42bd7d96c8ebae6
#   Stored in directory: /root/.cache/pip/wheels/c3/1b/47/ca78a979321cb4bf9e812da5157fb754712f43d094bc60bf61
# ...
#   Created wheel for docopt: filename=docopt-0.6.2-py2.py3-none-any.whl size=13707 sha256=3f147a7c77fb7360b1f1af6c34947f898f8ca97060c5570ba69caecd2128a4d6
#   Stored in directory: /root/.cache/pip/wheels/fc/ab/d4/5da2067ac95b36618c629a5f93f809425700506f72c9732fac
# Successfully built pipreqsnb docopt
# ...

# %% [markdown]
# install packages not included by default in colab so that the proper version is found by pipreqsnb

# %%
# !pip install scipy seaborn requests onedrivedownloader google-cloud google-colab livelossplot git+https://github.com/huggingface/transformers.git datasets albumentations torchinfo slicer MedPy
# Out:
# ...
#   Cloning https://github.com/huggingface/transformers.git to /tmp/pip-req-build-z4g22n2s
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /tmp/pip-req-build-z4g22n2s
#   Resolved https://github.com/huggingface/transformers.git to commit abaca9f9432a84cfaa95531de4c72334f38a42f2
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 486.2/486.2 kB 10.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.8/151.8 kB 21.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 50.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 26.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 72.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# generate the requirements.txt file

# %%
# !pipreqsnb --savepath '../requirements.txt' 'utils/pyenv_import_all_reqs.ipynb'
# Out:
# pipreqs  --savepath ../requirements.txt /content/drive/MyDrive/github/BioCV_Su23/src/__temp_pipreqsnb_folder
# WARNING: Import named "Pillow" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "Pillow" was resolved to "Pillow:10.0.0" package (https://pypi.org/project/Pillow/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "Requests" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "Requests" was resolved to "requests:2.31.0" package (https://pypi.org/project/requests/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# WARNING: Import named "scipy" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "scipy" was resolved to "scipy:1.11.1" package (https://pypi.org/project/scipy/).
# ...

# %% [markdown]
# Note: there is some extra editing required to match up scipy, seaborn, and Requests with what is in /usr/local/lib/python3.10/dist-packages as well removing a duplicate PILLOW entry and adding google-cloud and google-colab. This isn't perfect but it works for now ...
